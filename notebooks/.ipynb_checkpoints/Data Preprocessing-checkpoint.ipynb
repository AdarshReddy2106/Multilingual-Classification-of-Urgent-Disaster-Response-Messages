# %% [markdown]
# # **Data Preprocessing & Exploratory Data Analysis**
#
# This notebook:
# 1. Loads all HumAID TSV files (set1 + set2, 17 events)
# 2. Maps 11 HumAID labels → 5 target classes
# 3. Preprocesses tweet text
# 4. Exploratory Data Analysis
# 5. Saves processed data for downstream notebooks

# %%
import os
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import warnings
warnings.filterwarnings("ignore")
plt.rcParams["figure.dpi"] = 120

print("All imports successful!")
# Out:
# All imports successful!

# %% [markdown]
# ## 1. Configuration
#
# Update `BASE_DIR` to your local path. Everything else is derived from it.

# %%
BASE_DIR = r"C:\Users\muham\Documents\Acads\Sem 6\NLP\Project"

# %%
SET1_DIR = os.path.join(BASE_DIR, "HumAID_data_events_set1_47K", "events_set1")
SET2_DIR = os.path.join(BASE_DIR, "HumAID_data_events_set2_29K", "events_set2")

SET1_EVENTS = [
    "canada_wildfires_2016", "cyclone_idai_2019", "ecuador_earthquake_2016",
    "hurricane_harvey_2017", "hurricane_irma_2017", "hurricane_maria_2017",
    "hurricane_matthew_2016", "italy_earthquake_aug_2016",
    "kaikoura_earthquake_2016", "puebla_mexico_earthquake_2017",
    "srilanka_floods_2017",
]

SET2_EVENTS = [
    "california_wildfires_2018", "hurricane_dorian_2019",
    "hurricane_florence_2018", "kerala_floods_2018",
    "midwestern_us_floods_2019", "pakistan_earthquake_2019",
]

# %%
CLASS_ORDER = [
    "Critical Rescue",
    "Resource Requests",
    "Volunteering and Donations",
    "Situational Awareness",
    "Irrelevant",
]

CLASS_COLORS = {
    "Critical Rescue":             "#d32f2f",
    "Resource Requests":           "#ff9800",
    "Volunteering and Donations":  "#4caf50",
    "Situational Awareness":       "#2196f3",
    "Irrelevant":                  "#9e9e9e",
}

# %%
PROCESSED_CSV = os.path.join(BASE_DIR, "data", "processed", "humaid_processed.csv")
PLOTS_DIR = os.path.join(BASE_DIR, "results", "plots")
os.makedirs(os.path.dirname(PROCESSED_CSV), exist_ok=True)
os.makedirs(PLOTS_DIR, exist_ok=True)

# %% [markdown]
# ## 2. Load HumAID Data
#
# Loading all train/dev/test TSV files across both event sets.

# %%
all_dfs = []

for event_set, (events, base_path) in enumerate(
    [(SET1_EVENTS, SET1_DIR), (SET2_EVENTS, SET2_DIR)], start=1
):
    for event in events:
        event_dir = os.path.join(base_path, event)
        if not os.path.isdir(event_dir):
            print(f"  [WARNING] Not found: {event_dir}")
            continue

        for split_name in ["train", "dev", "test"]:
            filepath = os.path.join(event_dir, f"{event}_{split_name}.tsv")
            if not os.path.isfile(filepath):
                continue

            temp_df = pd.read_csv(filepath, sep="\t", quoting=3)
            temp_df["event"] = event
            temp_df["split"] = split_name
            temp_df["event_set"] = f"set{event_set}"
            all_dfs.append(temp_df)
            print(f"  {event}_{split_name}.tsv: {len(temp_df)} rows")
# Out:
#   canada_wildfires_2016_train.tsv: 1569 rows
#   canada_wildfires_2016_dev.tsv: 228 rows
#   canada_wildfires_2016_test.tsv: 445 rows
#   cyclone_idai_2019_train.tsv: 2753 rows
#   cyclone_idai_2019_dev.tsv: 401 rows
#   cyclone_idai_2019_test.tsv: 779 rows
#   ecuador_earthquake_2016_train.tsv: 1094 rows
#   ecuador_earthquake_2016_dev.tsv: 159 rows
#   ecuador_earthquake_2016_test.tsv: 310 rows
#   hurricane_harvey_2017_train.tsv: 6378 rows
#   hurricane_harvey_2017_dev.tsv: 929 rows
#   hurricane_harvey_2017_test.tsv: 1805 rows
#   hurricane_irma_2017_train.tsv: 6579 rows
#   hurricane_irma_2017_dev.tsv: 958 rows
#   hurricane_irma_2017_test.tsv: 1862 rows
#   hurricane_maria_2017_train.tsv: 5094 rows
#   hurricane_maria_2017_dev.tsv: 742 rows
#   hurricane_maria_2017_test.tsv: 1442 rows
#   hurricane_matthew_2016_train.tsv: 1157 rows
#   hurricane_matthew_2016_dev.tsv: 168 rows
#   hurricane_matthew_2016_test.tsv: 329 rows
#   italy_earthquake_aug_2016_train.tsv: 840 rows
#   italy_earthquake_aug_2016_dev.tsv: 122 rows
#   italy_earthquake_aug_2016_test.tsv: 239 rows
#   kaikoura_earthquake_2016_train.tsv: 1536 rows
#   kaikoura_earthquake_2016_dev.tsv: 224 rows
#   kaikoura_earthquake_2016_test.tsv: 435 rows
#   puebla_mexico_earthquake_2017_train.tsv: 1410 rows
#   puebla_mexico_earthquake_2017_dev.tsv: 205 rows
#   puebla_mexico_earthquake_2017_test.tsv: 400 rows
#   srilanka_floods_2017_train.tsv: 392 rows
#   srilanka_floods_2017_dev.tsv: 57 rows
#   srilanka_floods_2017_test.tsv: 111 rows
#   california_wildfires_2018_train.tsv: 5163 rows
#   california_wildfires_2018_dev.tsv: 752 rows
#   california_wildfires_2018_test.tsv: 1461 rows
#   hurricane_dorian_2019_train.tsv: 5329 rows
#   hurricane_dorian_2019_dev.tsv: 776 rows
#   hurricane_dorian_2019_test.tsv: 1508 rows
#   hurricane_florence_2018_train.tsv: 4384 rows
#   hurricane_florence_2018_dev.tsv: 639 rows
#   hurricane_florence_2018_test.tsv: 1241 rows
#   kerala_floods_2018_train.tsv: 5588 rows
#   kerala_floods_2018_dev.tsv: 814 rows
#   kerala_floods_2018_test.tsv: 1582 rows
#   midwestern_us_floods_2019_train.tsv: 1316 rows
#   midwestern_us_floods_2019_dev.tsv: 191 rows
#   midwestern_us_floods_2019_test.tsv: 373 rows
#   pakistan_earthquake_2019_train.tsv: 1370 rows
#   pakistan_earthquake_2019_dev.tsv: 199 rows
#   pakistan_earthquake_2019_test.tsv: 389 rows

# %%
df = pd.concat(all_dfs, ignore_index=True)

print(f"\n{'='*50}")
print(f"Total rows: {len(df)}")
print(f"  Set1: {len(df[df['event_set']=='set1'])}")
print(f"  Set2: {len(df[df['event_set']=='set2'])}")
print(f"  Events: {df['event'].nunique()}")
print(f"  Splits: {df['split'].value_counts().to_dict()}")
print(f"{'='*50}")
# Out:
# ==================================================
# Total rows: 74227
#   Set1: 41152
#   Set2: 33075
#   Events: 17
#   Splits: {'train': 51952, 'test': 14711, 'dev': 7564}
# ==================================================

# %%
print(f"Shape: {df.shape}")
print(f"Columns: {list(df.columns)}")
print(f"\nNull values:\n{df.isnull().sum()}")
print(f"\nOriginal HumAID label distribution:")
print(df["class_label"].value_counts())
df.head()
# Out:
# Shape: (74227, 6)
# Columns: ['tweet_id', 'tweet_text', 'class_label', 'event', 'split', 'event_set']
#
# Null values:
# tweet_id       0
# tweet_text     0
# class_label    0
# event          0
# split          0
# event_set      0
# dtype: int64
#
# Original HumAID label distribution:
# class_label
# rescue_volunteering_or_donation_effort    20849
# other_relevant_information                11848
# sympathy_and_support                       8499
# infrastructure_and_utility_damage          8046
# injured_or_dead_people                     6752
# not_humanitarian                           6145
# caution_and_advice                         5298
# displaced_people_and_evacuations           3999
# requests_or_urgent_needs                   2593
# missing_or_found_people                     198
# Name: count, dtype: int64
#              tweet_id                                         tweet_text  \
# 0  735891446960623616  RT @DonBradshawNTV: How @MarshallAmpsUK came t...
# 1  731202020296818688  Red Cross distributes $30M to Fort McMurray wi...
# 2  733665357236342784  Interesting insights on the shifting communica...
# 3  731963038429929472  RT @globeandmail: Oil sands producers helping ...
# 4  728674838034944001  Ottawa to match Red Cross donations for Fort M...
#
#                               class_label                  event  split  \
# 0              other_relevant_information  canada_wildfires_2016  train
# 1        displaced_people_and_evacuations  canada_wildfires_2016  train
# 2              other_relevant_information  canada_wildfires_2016  train
# 3  rescue_volunteering_or_donation_effort  canada_wildfires_2016  train
# 4  rescue_volunteering_or_donation_effort  canada_wildfires_2016  train
#
#   event_set
# 0      set1
# 1      set1
# 2      set1
# 3      set1
# 4      set1

# %% [markdown]
# ## 3. Map HumAID Labels → 5 Target Classes
#
# | HumAID Label | → Target Class |
# |---|---|
# | `requests_or_urgent_needs` + rescue keywords | **Critical Rescue** |
# | `requests_or_urgent_needs` (remaining) | **Resource Requests** |
# | `rescue_volunteering_or_donation_effort` | **Volunteering and Donations** |
# | `infrastructure_and_utility_damage`, `injured_or_dead_people`, `missing_or_found_people`, `displaced_people_and_evacuations`, `caution_and_advice`, `other_relevant_information` | **Situational Awareness** |
# | `not_humanitarian`, `sympathy_and_support`, `dont_know_cant_judge` | **Irrelevant** |
#
# For `requests_or_urgent_needs`, we use keyword matching to split life-threatening rescue situations from general resource requests.

# %%
LABEL_MAP = {
    "rescue_volunteering_or_donation_effort": "Volunteering and Donations",
    "infrastructure_and_utility_damage":      "Situational Awareness",
    "injured_or_dead_people":                 "Situational Awareness",
    "missing_or_found_people":                "Situational Awareness",
    "displaced_people_and_evacuations":       "Situational Awareness",
    "caution_and_advice":                     "Situational Awareness",
    "other_relevant_information":             "Situational Awareness",
    "not_humanitarian":                       "Irrelevant",
    "sympathy_and_support":                   "Irrelevant",
    "dont_know_cant_judge":                   "Irrelevant",
}

# %%
RESCUE_KEYWORDS = [
    r"\brescue\b", r"\btrapped\b", r"\bstranded\b", r"\bstuck\b",
    r"\bsave\s+us\b", r"\bhelp\s+us\b", r"\bmarooned\b", r"\bsinking\b",
    r"\bdrowning\b", r"\bevacuat\w*\b", r"\bsos\b", r"\bemergency\b",
    r"\blife.?threatening\b", r"\bdying\b", r"\bplease\s+come\b",
    r"\bsend\s+help\b", r"\burgent\w*\s+help\b", r"\bimmediate\w*\s+help\b",
    r"\bsave\s+them\b", r"\bsave\s+lives\b", r"\bairlifted\b",
]
RESCUE_PATTERN = re.compile("|".join(RESCUE_KEYWORDS), re.IGNORECASE)

# %%
def map_single_label(row):
    label = row["class_label"]
    text = str(row["tweet_text"])
    if label == "requests_or_urgent_needs":
        return "Critical Rescue" if RESCUE_PATTERN.search(text) else "Resource Requests"
    return LABEL_MAP.get(label, "Irrelevant")


df["target_label"] = df.apply(map_single_label, axis=1)

# %%
# Mapping summary
print("Label mapping summary:")
print("-" * 60)
mapping_check = df.groupby(["class_label", "target_label"]).size().reset_index(name="count")
print(mapping_check.to_string(index=False))
# Out:
# Label mapping summary:
# ------------------------------------------------------------
#                            class_label               target_label  count
#                     caution_and_advice      Situational Awareness   5298
#       displaced_people_and_evacuations      Situational Awareness   3999
#      infrastructure_and_utility_damage      Situational Awareness   8046
#                 injured_or_dead_people      Situational Awareness   6752
#                missing_or_found_people      Situational Awareness    198
#                       not_humanitarian                 Irrelevant   6145
#             other_relevant_information      Situational Awareness  11848
#               requests_or_urgent_needs            Critical Rescue    439
#               requests_or_urgent_needs          Resource Requests   2154
# rescue_volunteering_or_donation_effort Volunteering and Donations  20849
#                   sympathy_and_support                 Irrelevant   8499

# %%
urgent = df[df["class_label"] == "requests_or_urgent_needs"]
print(f"Total 'requests_or_urgent_needs': {len(urgent)}")
print(f"  → Critical Rescue:   {len(urgent[urgent['target_label'] == 'Critical Rescue'])}")
print(f"  → Resource Requests: {len(urgent[urgent['target_label'] == 'Resource Requests'])}")
# Out:
# Total 'requests_or_urgent_needs': 2593
#   → Critical Rescue:   439
#   → Resource Requests: 2154

# %%
print(f"\nSample Critical Rescue tweets:")
cr = urgent[urgent["target_label"] == "Critical Rescue"]
for _, row in cr.sample(min(5, len(cr)), random_state=42).iterrows():
    print(f"  > {row['tweet_text'][:140]}")

print(f"\nSample Resource Requests tweets:")
rr = urgent[urgent["target_label"] == "Resource Requests"]
for _, row in rr.sample(min(5, len(rr)), random_state=42).iterrows():
    print(f"  > {row['tweet_text'][:140]}")
# Out:
# Sample Critical Rescue tweets:
#   > @pulte @pulte can you do ANYTHING to help out a single mother with a 3 year old trach baby who is going to need to evacuate for #HurricaneDo
#   > ‼️ URGENT ‼️ PORT ARTHUR AND BEAUMONT TEXAS #Harvey #Floods #SOS
#   > At @tissforeveryone we are organizing collection drives for #KeralaFloods including medicines, blankets, bedsheets. Local districts had sent
#   > ⚠️IF YOU LIVE IN FLORIDA, OR KNOWS ANYONE WHO DOES, PLEASE SHARE MY THREAD THAT IS PINNED INFORMATION NEEDS TO BE SHARED IMMEDIATELY!!!! @Tw
#   > Dear @nsitharaman: 11 people including my family are stranded on the terrace of 2/334, Kavunkal House, Ward 2, Vilakkumadam Kottaram, Edayar
#
# Sample Resource Requests tweets:
#   > @pulte If you can, donate your airline miles to #HurricaneDorian victims.
#   > College of Engineering, Chengannur (CEC) is a major relief camp at #Chengannur. They are facing a serious FOOD shortage now. Please leverage
#   > Food, water, power, gasoline desperately needed in #PuertoRico. Not tomorrow, not next week, but NOW.
#   > Pet food needed in TX
#   > RT @SrBachchan: situation is very scary .. please help

# %% [markdown]
# ## 4. Text Preprocessing
#
# Cleaning steps:
# - Remove URLs
# - Remove RT (retweet) prefix
# - Remove @mentions
# - Normalize hashtags (`#KeralaFloods` → `KeralaFloods`)
# - Decode HTML entities (`&amp;` → `and`)
# - Remove special characters (keep basic punctuation)
# - Normalize whitespace
# - Lowercase
#
# Hashtag words are kept because they carry semantic meaning in disaster tweets.

# %%
def preprocess_text(text):
    text = str(text)
    text = re.sub(r"http\S+|www\.\S+", "", text)
    text = re.sub(r"^RT\s+", "", text)
    text = re.sub(r"@\w+", "", text)
    text = re.sub(r"#(\w+)", r"\1", text)
    text = re.sub(r"&amp;", "and", text)
    text = re.sub(r"&lt;", "<", text)
    text = re.sub(r"&gt;", ">", text)
    text = re.sub(r"[^\w\s.,!?'-]", " ", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text.lower()

df["clean_text"] = df["tweet_text"].apply(preprocess_text)

# %%
# Drop empty rows after cleaning
empty_mask = df["clean_text"].str.strip() == ""
print(f"Dropped {empty_mask.sum()} empty rows after cleaning")
df = df[~empty_mask].reset_index(drop=True)

# Before / after examples
print(f"\nPreprocessed {len(df)} rows. Examples:")
print("-" * 70)
for _, row in df.sample(1, random_state=42).iterrows():
    print(f"  ORIG:  {row['tweet_text'][:100]}")
    print(f"  CLEAN: {row['clean_text'][:100]}")
    print()
# Out:
# Dropped 0 empty rows after cleaning
#
# Preprocessed 74227 rows. Examples:
# ----------------------------------------------------------------------
#   ORIG:  Media to emphasize Use Ananthapadmanaba temple treasure to Kerala flood relief work
#   CLEAN: media to emphasize use ananthapadmanaba temple treasure to kerala flood relief work

# %% [markdown]
# ## 5. Exploratory Data Analysis

# %% [markdown]
# ### 5.1 Target Class Distribution

# %%
counts = df["target_label"].value_counts().reindex(CLASS_ORDER)
bar_colors = [CLASS_COLORS[c] for c in counts.index]

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

counts.plot(kind="bar", ax=axes[0], color=bar_colors, edgecolor="white")
axes[0].set_title("Class Distribution (Count)", fontsize=13)
axes[0].set_ylabel("Number of Tweets")
axes[0].tick_params(axis="x", rotation=30)
for i, v in enumerate(counts.values):
    axes[0].text(i, v + 100, f"{v:,}", ha="center", fontsize=9, fontweight="bold")

counts.plot(kind="pie", ax=axes[1], autopct="%1.1f%%", colors=bar_colors,
            textprops={"fontsize": 9})
axes[1].set_ylabel("")
axes[1].set_title("Class Distribution (%)", fontsize=13)

plt.tight_layout()
plt.savefig(os.path.join(PLOTS_DIR, "class_distribution.png"), dpi=150, bbox_inches="tight")
plt.show()

print("\nExact counts and percentages:")
for cls in CLASS_ORDER:
    c = counts[cls]
    print(f"  {cls:30s}: {c:6,}  ({c/len(df)*100:.1f}%)")
# Out:
# Exact counts and percentages:
#   Critical Rescue               :    439  (0.6%)
#   Resource Requests             :  2,154  (2.9%)
#   Volunteering and Donations    : 20,849  (28.1%)
#   Situational Awareness         : 36,141  (48.7%)
#   Irrelevant                    : 14,644  (19.7%)

# %% [markdown]
# ### 5.2 Class Imbalance Analysis

# %%
majority = counts.max()
print("Imbalance ratios (majority class / each class):")
for cls in CLASS_ORDER:
    ratio = majority / counts[cls]
    print(f"  {cls:30s}: {ratio:.1f}x")

print(f"\nMost underrepresented: {counts.idxmin()} ({counts.min():,})")
print(f"Most overrepresented:  {counts.idxmax()} ({counts.max():,})")
print(f"\n→ Will use class_weight='balanced' in all classifiers to handle this.")
# Out:
# Imbalance ratios (majority class / each class):
#   Critical Rescue               : 82.3x
#   Resource Requests             : 16.8x
#   Volunteering and Donations    : 1.7x
#   Situational Awareness         : 1.0x
#   Irrelevant                    : 2.5x
#
# Most underrepresented: Critical Rescue (439)
# Most overrepresented:  Situational Awareness (36,141)
#
# → Will use class_weight='balanced' in all classifiers to handle this.

# %% [markdown]
# ### 5.3 Text Length Analysis

# %%
df["text_length"] = df["clean_text"].astype(str).apply(len)
df["word_count"] = df["clean_text"].astype(str).apply(lambda x: len(x.split()))

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

for label in CLASS_ORDER:
    subset = df[df["target_label"] == label]
    axes[0].hist(subset["text_length"], bins=50, alpha=0.5,
                 label=label, color=CLASS_COLORS[label])
axes[0].set_title("Character Length Distribution", fontsize=13)
axes[0].set_xlabel("Characters")
axes[0].set_ylabel("Frequency")
axes[0].legend(fontsize=8)

for label in CLASS_ORDER:
    subset = df[df["target_label"] == label]
    axes[1].hist(subset["word_count"], bins=40, alpha=0.5,
                 label=label, color=CLASS_COLORS[label])
axes[1].set_title("Word Count Distribution", fontsize=13)
axes[1].set_xlabel("Words")
axes[1].set_ylabel("Frequency")
axes[1].legend(fontsize=8)

plt.tight_layout()
plt.savefig(os.path.join(PLOTS_DIR, "text_lengths.png"), dpi=150, bbox_inches="tight")
plt.show()

# %%
print("Text length statistics per class (word count):")
print("-" * 70)
stats = df.groupby("target_label")["word_count"].describe()[["mean", "std", "min", "50%", "max"]]
stats = stats.reindex(CLASS_ORDER)
stats.columns = ["Mean", "Std", "Min", "Median", "Max"]
print(stats.round(1))
# Out:
# Text length statistics per class (word count):
# ----------------------------------------------------------------------
#                             Mean   Std  Min  Median   Max
# target_label
# Critical Rescue             25.5  11.5  3.0    22.0  61.0
# Resource Requests           20.3  10.2  3.0    19.0  56.0
# Volunteering and Donations  22.0  10.7  3.0    19.0  76.0
# Situational Awareness       20.5  10.5  3.0    18.0  60.0
# Irrelevant                  22.9  11.4  3.0    20.0  62.0

# %% [markdown]
# ### 5.4 Class Distribution per Event

# %%
event_class = pd.crosstab(df["event"], df["target_label"]).reindex(columns=CLASS_ORDER)
event_class_pct = event_class.div(event_class.sum(axis=1), axis=0)

fig, ax = plt.subplots(figsize=(14, 7))
event_class_pct.plot(
    kind="barh", stacked=True, ax=ax,
    color=[CLASS_COLORS[c] for c in CLASS_ORDER],
    edgecolor="white", linewidth=0.5,
)
ax.set_title("Class Distribution per Disaster Event", fontsize=13)
ax.set_xlabel("Proportion")
ax.legend(bbox_to_anchor=(1.02, 1), loc="upper left", fontsize=9)
plt.tight_layout()
plt.savefig(os.path.join(PLOTS_DIR, "per_event_distribution.png"), dpi=150, bbox_inches="tight")
plt.show()

print("Samples per event:")
print(df["event"].value_counts().to_string())
# Out:
# Samples per event:
# event
# hurricane_irma_2017              9399
# hurricane_harvey_2017            9112
# kerala_floods_2018               7984
# hurricane_dorian_2019            7613
# california_wildfires_2018        7376
# hurricane_maria_2017             7278
# hurricane_florence_2018          6264
# cyclone_idai_2019                3933
# canada_wildfires_2016            2242
# kaikoura_earthquake_2016         2195
# puebla_mexico_earthquake_2017    2015
# pakistan_earthquake_2019         1958
# midwestern_us_floods_2019        1880
# hurricane_matthew_2016           1654
# ecuador_earthquake_2016          1563
# italy_earthquake_aug_2016        1201
# srilanka_floods_2017              560

# %% [markdown]
# ### 5.5 Top Words per Class

# %%
STOPWORDS = set([
    "the", "a", "an", "is", "are", "was", "were", "be", "been", "being",
    "have", "has", "had", "do", "does", "did", "will", "would", "could",
    "should", "may", "might", "shall", "can", "to", "of", "in", "for",
    "on", "with", "at", "by", "from", "as", "into", "through", "during",
    "before", "after", "above", "below", "between", "out", "off", "over",
    "under", "again", "further", "then", "once", "and", "but", "or", "nor",
    "not", "so", "very", "just", "about", "up", "its", "it", "this", "that",
    "these", "those", "i", "me", "my", "we", "our", "you", "your", "he",
    "him", "his", "she", "her", "they", "them", "their", "what", "which",
    "who", "whom", "how", "all", "each", "every", "both", "few", "more",
    "most", "other", "some", "such", "no", "only", "same", "than", "too",
    "also", "rt", "amp", "via", "get", "got", "one", "two", "new", "like",
    "people", "now", "need", "many", "much", "still", "please",
])

fig, axes = plt.subplots(2, 3, figsize=(16, 10))
axes = axes.flatten()

for idx, label in enumerate(CLASS_ORDER):
    subset = df[df["target_label"] == label]["clean_text"]
    all_words = " ".join(subset).split()
    filtered = [w for w in all_words if w not in STOPWORDS and len(w) > 2]
    top_20 = Counter(filtered).most_common(20)

    words, freq = zip(*top_20) if top_20 else ([], [])
    axes[idx].barh(range(len(words)), freq, color=CLASS_COLORS[label])
    axes[idx].set_yticks(range(len(words)))
    axes[idx].set_yticklabels(words, fontsize=8)
    axes[idx].invert_yaxis()
    axes[idx].set_title(label, fontsize=11, fontweight="bold")
    axes[idx].set_xlabel("Frequency")

axes[5].set_visible(False)

plt.suptitle("Top 20 Words per Class (excluding stopwords)", fontsize=14, y=1.01)
plt.tight_layout()
plt.savefig(os.path.join(PLOTS_DIR, "top_words_per_class.png"), dpi=150, bbox_inches="tight")
plt.show()

# %% [markdown]
# ### 5.6 Sample Tweets per Class

# %%
for label in CLASS_ORDER:
    subset = df[df["target_label"] == label]
    print(f"\n{'='*70}")
    print(f"  {label}  ({len(subset):,} samples)")
    print(f"{'='*70}")
    for _, row in subset.sample(min(2, len(subset)), random_state=42).iterrows():
        print(f"  [{row['event']}]")
        print(f"  > {row['tweet_text'][:150]}")
        print()
# Out:
# ======================================================================
#   Critical Rescue  (439 samples)
# ======================================================================
#   [hurricane_dorian_2019]
#   > @pulte @pulte can you do ANYTHING to help out a single mother with a 3 year old trach baby who is going to need to evacuate for #HurricaneDorian this
#
#   [hurricane_harvey_2017]
#   > ‼️ URGENT ‼️ PORT ARTHUR AND BEAUMONT TEXAS #Harvey #Floods #SOS
#
#
# ======================================================================
#   Resource Requests  (2,154 samples)
# ======================================================================
#   [hurricane_dorian_2019]
#   > @pulte If you can, donate your airline miles to #HurricaneDorian victims.
#
#   [kerala_floods_2018]
#   > College of Engineering, Chengannur (CEC) is a major relief camp at #Chengannur. They are facing a serious FOOD shortage now. Please leverage your cont
#
#
# ======================================================================
#   Volunteering and Donations  (20,849 samples)
# ======================================================================
#   [midwestern_us_floods_2019]
#   > I spent some time in Verdigre today. Thanks to our friends in PA for this load of hay. Also met a convoy of trucks in Norfolk NE hauling hay and fenci
#
#   [kerala_floods_2018]
#   > While there are many people helping #rebuildkerala it is important to do it the right way, to assess the critical needs and providing the right kind o
#
#
# ======================================================================
#   Situational Awareness  (36,141 samples)
# ======================================================================
#   [kerala_floods_2018]
#   > Snake Alert in Kerala as People Return Home in Flood Ravaged State, Hospitals Stocking Anti-Venom
#
#   [hurricane_dorian_2019]
#   > Be prepared to keep your food safe during a #hurricane with these important safety tips from @US_FDA and @CDCgov: - Make &amp; store ice - Keep cooler
#
#
# ======================================================================
#   Irrelevant  (14,644 samples)
# ======================================================================
#   [italy_earthquake_aug_2016]
#   > RT @crybabycliffxrd: I just saw the news this is so sad my thoughts go out to the ones who got affected by the earthquake #PrayForItaly
#
#   [kerala_floods_2018]
#   > Good morning Let us pray earnestly to the Lord for the flood victims of Kerala as they have started cleaning their homes may not be despaired seeing t

# %% [markdown]
# ### 5.7 Train vs Test Class Balance

# %%
train_counts = df[df["split"]=="train"]["target_label"].value_counts().reindex(CLASS_ORDER)
test_counts  = df[df["split"]=="test"]["target_label"].value_counts().reindex(CLASS_ORDER)

train_pct = (train_counts / train_counts.sum() * 100).round(1)
test_pct  = (test_counts / test_counts.sum() * 100).round(1)

balance_df = pd.DataFrame({
    "Train Count": train_counts,
    "Train %": train_pct,
    "Test Count": test_counts,
    "Test %": test_pct,
})
print(balance_df)

x = np.arange(len(CLASS_ORDER))
width = 0.35

fig, ax = plt.subplots(figsize=(10, 5))
ax.bar(x - width/2, train_pct, width, label="Train", alpha=0.8)
ax.bar(x + width/2, test_pct, width, label="Test", alpha=0.8)
ax.set_ylabel("Percentage (%)")
ax.set_title("Class Distribution: Train vs Test", fontsize=13)
ax.set_xticks(x)
ax.set_xticklabels(CLASS_ORDER, rotation=20, ha="right")
ax.legend()
plt.tight_layout()
plt.savefig(os.path.join(PLOTS_DIR, "train_test_balance.png"), dpi=150, bbox_inches="tight")
plt.show()
# Out:
#                             Train Count  Train %  Test Count  Test %
# target_label
# Critical Rescue                     315      0.6          90     0.6
# Resource Requests                  1500      2.9         426     2.9
# Volunteering and Donations        14591     28.1        4133    28.1
# Situational Awareness             25297     48.7        7160    48.7
# Irrelevant                        10249     19.7        2902    19.7

# %% [markdown]
# ## 6. Save Processed Data
#
# This CSV will be loaded by all downstream notebooks (baselines, XLM-RoBERTa, etc.)

# %%
df.to_csv(PROCESSED_CSV, index=False)

print(f"Saved {len(df)} rows to {PROCESSED_CSV}")
print(f"Columns: {list(df.columns)}")
print(f"File size: {os.path.getsize(PROCESSED_CSV) / (1024*1024):.1f} MB")

print(f"\nSplit breakdown:")
print(f"  Train: {len(df[df['split']=='train'])}")
print(f"  Dev:   {len(df[df['split']=='dev'])}")
print(f"  Test:  {len(df[df['split']=='test'])}")
# Out:
# Saved 74227 rows to C:\Users\muham\Documents\Acads\Sem 6\NLP\Project\data\processed\humaid_processed.csv
# Columns: ['tweet_id', 'tweet_text', 'class_label', 'event', 'split', 'event_set', 'target_label', 'clean_text', 'text_length', 'word_count']
# File size: 27.4 MB
#
# Split breakdown:
#   Train: 51952
#   Dev:   7564
#   Test:  14711

# %% [markdown]
# ## 7. Key Takeaways
#
# - **Class imbalance** is significant — Critical Rescue is the rarest class, Volunteering and Donations likely the largest. All classifiers must use balanced class weights.
# - **Rescue keyword heuristic** splits `requests_or_urgent_needs` reasonably, but review the samples above to check if the split makes sense for your data.
# - **Train/test proportions** are consistent across classes (HumAID's built-in split).
# - **Hashtag words** carry strong class signal (e.g., "donate", "rescue", "damage").
